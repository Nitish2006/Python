# %%
import requests
import json

url = "https://mnfmsopodocbceojqwvh.supabase.co/rest/v1/events?select=*"
api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Im1uZm1zb3BvZG9jYmNlb2pxd3ZoIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDQxMDk0MzgsImV4cCI6MjA1OTY4NTQzOH0.iUbbvENS1LaYN_Wa5GY2u26yKC_F2hUdvQQrjqWfdwE"

headers = {
    "apikey": api_key,
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))
else:
    print("Error:", response.status_code, response.text)
# Out:
# [
#     {
#         "id": "83be4dad-135f-4c1f-85f0-de7bb3c02973",
#         "title": "HACKATHON-BUILD BHARAT THROUGH AI",
# ...

# %%
import requests

url = "https://netflix-api-g992.onrender.com/login"
payload = {
    "email": "your_email@example.com",
    "password": "your_password"
}

response = requests.post(url, json=payload)

if response.status_code == 200:
    print("Login Success:")
    print(response.json())  # Usually returns a token or user info
else:
    print("Login Failed:", response.status_code, response.text)
# Out:
# Login Failed: 404 {"message":"Page Not Found"}
